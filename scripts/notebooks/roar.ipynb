# %% [markdown]
# # Remove and Retrain (ROAR)

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts
sys.path.insert(0, os.getcwd() + '/../../')  # for plots

from scripts import roar
from scripts.plot import plot_roar

# %%
args = roar.Args()
args.dataset='adult'
args.tree_type='cb'
args.n_estimators=100
args.max_depth=None
args.tree_kernel='tree_output'
args.kernel_model='klr'
args.data_dir='../../data/'
roar.main(args)
# Out:
# <scripts.roar.Args object at 0x11dec6fd0>
#
# Seed: 1
# no. train instances: 32,561
# no. test instances: 16,281
# no. features: 14
#
# train acc: 0.883, auc: 0.937, logloss: 0.265
# test  acc: 0.868, auc: 0.923, logloss: 0.286
#
# ordering by random...
# 100%|██████████| 10/10 [00:06<00:00,  1.88it/s]
# time: 6.921103s
#
# ordering by our method...
# TREX:
# transforming training data...
# tuning...
# [Fold 1] C=0.01 : 1.278s; corr=0.909
# [Fold 1] C=0.1  : 1.260s; corr=0.957
# [Fold 1] C=1.0  : 1.574s; corr=0.968
# [Fold 1] C=10.0 : 1.339s; corr=0.946
# [Fold 1] C=100.0: 1.374s; corr=0.915
# [Fold 2] C=0.01 : 1.819s; corr=0.915
# [Fold 2] C=0.1  : 1.391s; corr=0.958
# [Fold 2] C=1.0  : 1.316s; corr=0.964
# [Fold 2] C=10.0 : 1.459s; corr=0.937
# [Fold 2] C=100.0: 1.434s; corr=0.910
# chosen C: 1.0
# total tuning time: 14.270s
# training...
# total training time: 22.724s
# 100%|██████████| 16281/16281 [02:02<00:00, 189.09it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.53it/s]
# time: 186.418688s

# %%
args = plot_roar.Args()
args.dataset=['adult']
plot_roar.main(args)
