# %% [markdown]
# # Tree and SVM Prediction Fidelity
# This notebook analyzes the correlation between tree ensemble probabilities and an SVM decision values.

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts
sys.path.insert(0, os.getcwd() + '/../../')  # for util

from scripts.prediction import prediction
data_dir = '../../data'

# %% [markdown]
# ## Prediction Correlation
# This section looks at the correlation between the predictions of a learned tree ensemble, and an SVM trained on top of that tree ensemble. We want to see how this correlation varies between train and test predictions for different models, feature representations, and datasets.

# %%
prediction(model='cb', encoding='tree_output', dataset='breast', n_estimators=100, random_state=1, k=1000, data_dir=data_dir, timeit=True)
# Out:
# train feature extraction took 0.2748289108276367s
# fitting svm took 0.006493091583251953s

# %%
prediction(model='cb', encoding='tree_output', dataset='adult', n_estimators=100, random_state=1, k=1000, data_dir=data_dir, timeit=True)
# Out:
# train feature extraction took 16.58162808418274s
# fitting svm took 17.25718092918396s

# %%
prediction(model='cb', encoding='tree_output', dataset='amazon', n_estimators=100, random_state=1, k=1000, data_dir=data_dir, timeit=True)
# Out:
# train feature extraction took 13.536187171936035s
# fitting svm took 1.0711688995361328s

# %%
prediction(model='cb', encoding='tree_output', dataset='medifor', n_estimators=100, random_state=1, k=1000, data_dir=data_dir, timeit=True)
# Out:
# train feature extraction took 2.1142971515655518s
# fitting svm took 0.35229992866516113s
