# %% [markdown]
# # Tree and SVM Prediction Fidelity
# This notebook analyzes the correlation between tree ensemble probabilities and an SVM decision values.

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts
sys.path.insert(0, os.getcwd() + '/../../')  # for util

from scripts.prediction import prediction
data_dir = '../../data'
# Out:
# /Users/Jonny/Documents/research/interpretability/classification/trees/myenv/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %% [markdown]
# ## Using tree ensemble predicted labels vs true labels
# This section looks at the correlation between the predictions of a learned tree ensemble, and an SVM trained on top of that tree ensemble. We want to see how this correlation varies between train and test predictions for different models, feature representations, and datasets.

# %% [markdown]
# ## Breast

# %%
prediction(model='cb', dataset='breast', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 0.527s
# tree_output and true_label=False took 0.563s
# tree_path and true_label=True took 0.170s
# tree_path and true_label=False took 0.176s

# %% [markdown]
# ## Adult

# %%
prediction(model='cb', dataset='adult', n_estimators=100, random_state=1, k=None, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 157.164s
# tree_output and true_label=False took 74.756s
# tree_path and true_label=True took 726.376s
# tree_path and true_label=False took 138.735s

# %% [markdown]
# ## Amazon

# %%
prediction(model='cb', dataset='amazon', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 59.696s
# tree_output and true_label=False took 33.332s
# tree_path and true_label=True took 201.989s
# tree_path and true_label=False took 15.764s

# %% [markdown]
# ## Medifor

# %%
prediction(model='cb', dataset='medifor', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 14.228s
# tree_output and true_label=False took 13.714s
# tree_path and true_label=True took 13.983s
# tree_path and true_label=False took 10.958s

# %% [markdown]
# ## Medifor1a

# %%
prediction(model='cb', dataset='medifor1a', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a919eb9944b> in <module>
# ----> 1 prediction(model='cb', dataset='medifor1a', n_estimators=100, random_state=1, data_dir=data_dir)
#
# NameError: name 'prediction' is not defined

# %% [markdown]
# ## Medifor1b

# %%
prediction(model='cb', dataset='medifor1b', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 25.528s
# tree_output and true_label=False took 21.210s
# tree_path and true_label=True took 66.058s
# tree_path and true_label=False took 34.988s

# %% [markdown]
# ## Medifor2

# %%
prediction(model='cb', dataset='medifor2', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 78.303s
# tree_output and true_label=False took 49.609s
# tree_path and true_label=True took 278.962s
# tree_path and true_label=False took 78.079s

# %% [markdown]
# ## Churn

# %%
prediction(model='cb', dataset='churn', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 9.636s
# tree_output and true_label=False took 7.756s
# tree_path and true_label=True took 22.068s
# tree_path and true_label=False took 6.227s

# %% [markdown]
# ## Heart

# %%
prediction(model='cb', dataset='heart', n_estimators=100, random_state=1, data_dir=data_dir)
# Out:
# tree_output and true_label=True took 0.566s
# tree_output and true_label=False took 0.619s
# tree_path and true_label=True took 0.236s
# tree_path and true_label=False took 0.213s
