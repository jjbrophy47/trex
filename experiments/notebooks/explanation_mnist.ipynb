# %% [markdown]
# # MNIST

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts
sys.path.insert(0, os.getcwd() + '/../../')  # for util

from scripts.explanation_mnist import prediction_explanation
data_dir = '../../data'

# %% [markdown]
# ## Explanations for Test Instances
# This looks at sample-based explanations for individual test predictions. We show the raw images for the test instance, and the raw images for the most impactful positive and negative train instances.

# %% [markdown]
# ### 2s and 7s

# %%
prediction_explanation(model='lgb', encoding='tree_output', dataset='mnist_27', random_state=8, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 12223
# test instances: 2060
# labels: [2, 7]
# reducing dimensionality from 784 to 50 using PCA...
# fitting an lgb model...
# fitting tree explainer...
# train feature extraction took 3.738252639770508s
# fitting svm took 0.42073965072631836s
#
# Tree Explainer:
# train shape: (12223, 50)
# classes: [2 7]
# encoding: tree_output
# sparse: False
# kernel: rbf
# fit predicted labels: True
# C: 0.1
# gamma: scale
# random state: 8
#
# model (LGBMClassifier)
# train set acc: 1.000000
# train log loss: 0.00117
# train auroc: 1.000
# test set acc: 0.982039
# test log loss: 0.06096
# test auroc: 0.998

# %%
prediction_explanation(model='cb', encoding='tree_output', dataset='mnist_27', random_state=8, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 12223
# test instances: 2060
# labels: [2, 7]
# reducing dimensionality from 784 to 50 using PCA...
# fitting an cb model...
# fitting tree explainer...
# train feature extraction took 6.101282119750977s
# fitting svm took 1.073547124862671s
#
# Tree Explainer:
# train shape: (12223, 50)
# classes: [0. 1.]
# encoding: tree_output
# sparse: False
# kernel: rbf
# fit predicted labels: True
# C: 0.1
# gamma: scale
# random state: 8
#
# model (CatBoostClassifier)
# train set acc: 0.000000
# train log loss: 0.00808
# train auroc: 1.000
# test set acc: 0.000000
# test log loss: 0.05222
# test auroc: 0.998

# %%
prediction_explanation(model='xgb', encoding='tree_output', dataset='mnist_27', random_state=8, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 12223
# test instances: 2060
# labels: [2, 7]
# reducing dimensionality from 784 to 50 using PCA...
# fitting an xgb model...
# fitting tree explainer...
# train feature extraction took 1.14493727684021s
# fitting svm took 1.9814059734344482s
#
# Tree Explainer:
# train shape: (12223, 50)
# classes: [2 7]
# encoding: tree_output
# sparse: False
# kernel: rbf
# fit predicted labels: True
# C: 0.1
# gamma: scale
# random state: 8
#
# model (XGBClassifier)
# train set acc: 0.993537
# train log loss: 0.02954
# train auroc: 1.000
# test set acc: 0.981068
# test log loss: 0.06337
# test auroc: 0.997

# %% [markdown]
# ### 1s, 2s, and 7s

# %%
prediction_explanation(model='lgb', encoding='tree_output', dataset='mnist_127', random_state=8, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 18965
# test instances: 3195
# labels: [1, 2, 7]
# reducing dimensionality from 784 to 50 using PCA...
# fitting lgb model...
# fitting tree explainer...
# train feature extraction took 18.842090129852295s
# fitting svm took 10.879005908966064s
#
# Tree Explainer:
# train shape: (18965, 50)
# classes: [1 2 7]
# encoding: tree_output
# sparse: False
# kernel: rbf
# fit predicted labels: True
# C: 0.1
# gamma: scale
# random state: 8
#
# model (LGBMClassifier)
# train set acc: 1.000000
# train log loss: 0.00258
# test set acc: 0.985290
# test log loss: 0.04693

# %% [markdown]
# ### 4s and 9s

# %%
prediction_explanation(model='lgb', encoding='tree_output', dataset='mnist_49', random_state=8, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 11791
# test instances: 1991
# labels: [4, 9]
# reducing dimensionality from 784 to 50 using PCA...
# fitting lgb model...
# fitting tree explainer...
# train feature extraction took 3.704779863357544s
# fitting svm took 0.9619178771972656s
#
# Tree Explainer:
# train shape: (11791, 50)
# classes: [4 9]
# encoding: tree_output
# sparse: False
# kernel: rbf
# fit predicted labels: True
# C: 0.1
# gamma: scale
# random state: 8
#
# model (LGBMClassifier)
# train set acc: 0.999661
# train log loss: 0.02076
# train auroc: 1.000
# test set acc: 0.975892
# test log loss: 0.06847
# test auroc: 0.998

# %%
prediction_explanation(model='lgb', encoding='tree_output', dataset='mnist_69', random_state=8, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 11867
# test instances: 1967
# labels: [6, 9]
# reducing dimensionality from 784 to 50 using PCA...
# fitting lgb model...
# fitting tree explainer...
# train feature extraction took 3.7094480991363525s
# fitting svm took 0.20895099639892578s
#
# Tree Explainer:
# train shape: (11867, 50)
# classes: [6 9]
# encoding: tree_output
# sparse: False
# kernel: rbf
# fit predicted labels: True
# C: 0.1
# gamma: scale
# random state: 8
#
# model (LGBMClassifier)
# train set acc: 1.000000
# train log loss: 0.00006
# train auroc: 1.000
# test set acc: 0.993391
# test log loss: 0.02054
# test auroc: 1.000
