# %% [markdown]
# # MNIST

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts
sys.path.insert(0, os.getcwd() + '/../../')  # for util

from scripts.explanation_mnist import prediction_explanation
data_dir = '../../data'
# Out:
# /Users/Jonny/Documents/research/interpretability/classification/trees/myenv/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %% [markdown]
# ## Explanations for Test Instances
# This looks at sample-based explanations for individual test predictions. We show the raw images for the test instance, and the raw images for the most impactful positive and negative train instances.

# %%
prediction_explanation(model='lgb', encoding='tree_output', dataset='mnist_27', random_state=8, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 12223
# test instances: 2060
# labels: [2, 7]
# reducing dimensionality from 784 to 50 using PCA...
# fitting an lgb model...
# fitting sexee explainer...
# train feature extraction took 3.8259928226470947s
# fitting svm took 0.42642998695373535s
# model (LGBMClassifier)
# train set acc: 1.000000
# train log loss: 0.00114
# train auroc: 1.000
# test set acc: 0.981553
# test log loss: 0.06297
# test auroc: 0.998
# computing impact from train instances took 0.0020401477813720703s

# %%
prediction_explanation(model='cb', encoding='tree_output', dataset='mnist_27', random_state=5, topk_train=5, data_dir=data_dir)
# Out:
# train instances: 12223
# test instances: 2060
# labels: [2, 7]
# reducing dimensionality from 784 to 50 using PCA...
# fitting an cb model...
# fitting sexee explainer...
# train feature extraction took 6.888462066650391s
# fitting svm took 1.2303791046142578s
# model (CatBoostClassifier)
# train set acc: 0.000000
# train log loss: 0.00896
# train auroc: 1.000
# test set acc: 0.000000
# test log loss: 0.05862
# test auroc: 0.998
# computing impact from train instances took 0.0024709701538085938s
