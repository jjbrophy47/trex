# %% [markdown]
# # Runtime
# This notebook records the time it takes to train a linear model on the tree-extracted feature
# representation of the data and generate and instance-based explanation for a single query instance.

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts
sys.path.insert(0, os.getcwd() + '/../../')  # for util

from scripts.runtime import runtime
data_dir = '../../data'

# %% [markdown]
# ## Adult

# %%
# set Maple=True to compare against MAPLE
# set inf_k=-1 to compare against LeafInfluence
runtime(model_type='cb', dataset='adult', linear_model='svm', kernel='linear',
        encoding='leaf_output', true_label=True, repeats=10, random_state=1,
        maple=False, inf_k=None, data_dir=data_dir)
# Out:
# run 0
# train instances: 32561
# num features: 14
# model (CatBoostClassifier)
# test set acc: 0.868067
# test log loss: 0.28628
# test auroc: 0.922
# ours...
# fine tune: 34.809s
# test time: 0.138s
#
# run 1
# train instances: 32561
# num features: 14
# model (CatBoostClassifier)
# test set acc: 0.869234
# test log loss: 0.28671
# test auroc: 0.922
# ours...
# fine tune: 36.715s
# test time: 0.130s
#
# run 2
# train instances: 32561
# num features: 14
# model (CatBoostClassifier)
# test set acc: 0.870892
# test log loss: 0.28558
# test auroc: 0.923
# ours...
# fine tune: 39.371s
# test time: 0.134s
#
# run 3
# train instances: 32561
# num features: 14
# model (CatBoostClassifier)
# test set acc: 0.868804
# test log loss: 0.28468
# test auroc: 0.923
# ours...
# fine tune: 34.843s
# test time: 0.130s
#
# run 4
# train instances: 32561
# num features: 14
# model (CatBoostClassifier)
# test set acc: 0.869111
# test log loss: 0.28449
# test auroc: 0.924
# ours...
# fine tune: 35.267s
# ...

# %% [markdown]
# ## Amazon

# %%
# set Maple=True to compare against MAPLE
# set inf_k=-1 to compare against LeafInfluence
runtime(model_type='cb', dataset='amazon', linear_model='svm', kernel='linear',
        encoding='leaf_output', true_label=True, repeats=10, random_state=1,
        maple=False, inf_k=None, data_dir=data_dir)
# Out:
# run 0
# train instances: 26215
# num features: 9
# model (CatBoostClassifier)
# test set acc: 0.941562
# test log loss: 0.18488
# test auroc: 0.802
# ours...
# fine tune: 15.079s
# test time: 0.002s
#
# run 1
# train instances: 26215
# num features: 9
# model (CatBoostClassifier)
# test set acc: 0.941562
# test log loss: 0.18464
# test auroc: 0.808
# ours...
# fine tune: 15.922s
# test time: 0.002s
#
# run 2
# train instances: 26215
# num features: 9
# model (CatBoostClassifier)
# test set acc: 0.941715
# test log loss: 0.18452
# test auroc: 0.806
# ours...
# fine tune: 16.997s
# test time: 0.003s
#
# run 3
# train instances: 26215
# num features: 9
# model (CatBoostClassifier)
# test set acc: 0.940342
# test log loss: 0.18165
# test auroc: 0.818
# ours...
# fine tune: 16.433s
# test time: 0.002s
#
# run 4
# train instances: 26215
# num features: 9
# model (CatBoostClassifier)
# test set acc: 0.942325
# test log loss: 0.18640
# test auroc: 0.798
# ours...
# fine tune: 15.948s
# ...

# %% [markdown]
# ## Churn

# %%
# set Maple=True to compare against MAPLE
# set inf_k=-1 to compare against LeafInfluence
runtime(model_type='cb', dataset='churn', linear_model='svm', kernel='linear',
        encoding='leaf_output', true_label=True, repeats=10, random_state=1,
        maple=False, inf_k=None, data_dir=data_dir)
# Out:
# run 0
# train instances: 5634
# num features: 19
# model (CatBoostClassifier)
# test set acc: 0.795600
# test log loss: 0.41980
# test auroc: 0.843
# ours...
# fine tune: 4.409s
# test time: 0.012s
#
# run 1
# train instances: 5634
# num features: 19
# model (CatBoostClassifier)
# test set acc: 0.791341
# test log loss: 0.43174
# test auroc: 0.834
# ours...
# fine tune: 3.784s
# test time: 0.015s
#
# run 2
# train instances: 5634
# num features: 19
# model (CatBoostClassifier)
# test set acc: 0.779276
# test log loss: 0.44169
# test auroc: 0.826
# ours...
# fine tune: 3.794s
# test time: 0.011s
#
# run 3
# train instances: 5634
# num features: 19
# model (CatBoostClassifier)
# test set acc: 0.804116
# test log loss: 0.41774
# test auroc: 0.845
# ours...
# fine tune: 3.880s
# test time: 0.018s
#
# run 4
# train instances: 5634
# num features: 19
# model (CatBoostClassifier)
# test set acc: 0.804116
# test log loss: 0.42836
# test auroc: 0.840
# ours...
# fine tune: 3.954s
# ...
