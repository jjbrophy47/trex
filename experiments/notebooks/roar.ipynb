# %% [markdown]
# # Remove and Retrain (ROAR)

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts

from scripts import roar

# %%
args = roar.Args()
args.dataset='adult'
args.tree_type='cb'
args.tree_kernel='leaf_output'
args.data_dir='../../data/'
roar.main(args)
# Out:
# <scripts.roar.Args object at 0x125527048>
# train instances: 32,561
# val instances: 16,281
# no. features: 14
#
# train acc: 0.883, auc: 0.937, logloss: 0.265
# test  acc: 0.868, auc: 0.923, logloss: 0.286
# ordering by random...
# 100%|██████████| 10/10 [00:08<00:00,  1.54it/s]
# time: 8.586288s
# ordering by our method...
# saving model to: output/clustering/adult/models/trex_lr_leaf_output.pkl
# 100%|██████████| 16281/16281 [03:06<00:00, 87.09it/s]
# 100%|██████████| 10/10 [00:08<00:00,  1.49it/s]
# time: 238.263693s
