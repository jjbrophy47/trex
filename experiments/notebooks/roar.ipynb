# %% [markdown]
# # Remove and Retrain (ROAR)

# %%
import os
import sys
sys.path.insert(0, os.getcwd() + '/../')  # for scripts
sys.path.insert(0, os.getcwd() + '/../../')  # for plots

from scripts import roar
from scripts.plot import plot_roar

# %%
args = roar.Args()
args.dataset='adult'
args.tree_type='cb'
args.n_estimators=250
args.max_depth=5
args.tree_kernel='leaf_output'
args.kernel_model='lr'
args.data_dir='../../data/'
roar.main(args)
# Out:
# <scripts.roar.Args object at 0x10cbed4a8>
# train instances: 32,561
# val instances: 14,653
# test instances: 16,281
# no. features: 14
#
# train acc: 0.893, auc: 0.948, logloss: 0.245
# test  acc: 0.871, auc: 0.925, logloss: 0.282
# ordering by random...
# 100%|██████████| 10/10 [00:39<00:00,  3.34s/it]
# time: 39.276453s
# ordering by our method...
# 100%|██████████| 16281/16281 [06:43<00:00, 40.40it/s]
# 100%|██████████| 10/10 [00:38<00:00,  3.16s/it]
# time: 542.438490s

# %%
args = plot_roar.Args()
args.dataset=['adult']
plot_roar.main(args)
